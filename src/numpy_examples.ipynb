# %%
import numpy as np

# Display available functions and methods in numpy
def list_numpy_functions():
    np_functions = [func for func in dir(np) if not func.startswith('_')]
    return np_functions

# Demonstration of basic NumPy functions

# %%
# Array creation
array_1d = np.array([1, 2, 3, 4, 5])
array_2d = np.array([[1, 2, 3], [4, 5, 6]])
array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
zeros_array = np.zeros((3, 3))
ones_array = np.ones((3, 3))
random_array = np.random.rand(3, 3)
float_precision_array = np.array([1.234567, 2.345678, 3.456789], dtype=np.float32)

# Check if float128 is available
try:
    float128_array = np.array([1.234567890123456789, 2.34567890123456789, 3.4567890123456789], dtype=np.float64)
except AttributeError:
    float128_array = "np.float128 not available on this system"


# Printing results
print("NumPy Functions and Methods:")
print(list_numpy_functions())
print("\nArray Creation:")
print("1D Array:", array_1d)
print("2D Array:", array_2d)
print("3D Array:\n", array_3d)
print("Zeros Array:\n", zeros_array)
print("Ones Array:\n", ones_array)
print("Random Array:\n", random_array)
print("Float Precision Array (float32):", float_precision_array)
print("Float Precision Array (float128):", float128_array)
# Out:
# NumPy Functions and Methods:
# ...

# %%
array_flattened = array_1d.flatten(array_3d)
array_reshaped = array_2d.reshape((3, 2))

# %%
# Basic operations
sum_array = np.sum(array_1d)
mean_array = np.mean(array_1d)
std_array = np.std(array_1d)
max_value = np.max(array_1d)
min_value = np.min(array_1d)

# %%
# Indexing and slicing
first_element = array_1d[0]
last_element = array_1d[-1]
sub_array = array_1d[1:4]
sub_array_3d = array_3d[:, 0, :]  # Extracting the first row from each 2D matrix

# %%
# Linear Algebra
identity_matrix = np.eye(3)
matrix_product = np.dot(array_2d, identity_matrix)

# Eigen Operations
eigen_values, eigen_vectors = np.linalg.eig(identity_matrix)

# %%
# Universal Functions (ufuncs)
squared_array = np.square(array_1d)
sqrt_array = np.sqrt(array_1d)
exp_array = np.exp(array_1d)
log_array = np.log(array_1d)

# Printing results
print("NumPy Functions and Methods:")
print(list_numpy_functions())
print("\nArray Creation:")
print("1D Array:", array_1d)
print("2D Array:", array_2d)
print("3D Array:\n", array_3d)
print("Zeros Array:\n", zeros_array)
print("Ones Array:\n", ones_array)
print("Random Array:\n", random_array)
print("Float Precision Array (float32):", float_precision_array)
print("Float Precision Array (float128):", float128_array)
